# %%
from google import genai

client = genai.Client(api_key="AIzaSyA4SzcHUXZL6aKmqGVkstSkwZDHerijEfE")

response = client.models.generate_content(
    model="gemini-2.5-flash-preview-04-17",
    contents="""        You are a career expert. You will be provided with a list of skills and your task is to generate a detailed, step by step roadmap to learn those skills, also provide free or popular courses or articles with links.
        Generate a career roadmap for the skills: <sql>"""
)
print(response.text)
# Out:
# Okay, aspiring data wrangler! SQL is a foundational skill for many tech and data-related careers. It's the language of databases, allowing you to store, retrieve, and manipulate data efficiently.
#
# Here is a detailed, step-by-step roadmap to learn SQL, designed to take you from absolute beginner to a proficient level, along with popular free or accessible resources.
#
# **Understanding SQL:** SQL (Structured Query Language) is a standard programming language used for managing relational databases. It's essential for roles like Data Analyst, Data Scientist, Database Administrator, Business Intelligence Developer, and many types of software developers.
#
# **SQL Learning Roadmap**
#
# This roadmap assumes you are starting with no prior knowledge of SQL.
#
# ---
#
# **Step 1: Understand the Fundamentals & Setup Your Environment**
#
# *   **Goal:** Grasp what SQL is, why it's used, and get ready to practice.
# ...

# %%
from google import genai

client = genai.Client(api_key="AIzaSyA4SzcHUXZL6aKmqGVkstSkwZDHerijEfE")
chat = client.chats.create(model="gemini-2.5-flash-preview-04-17")

response = chat.send_message("I have 2 dogs in my house.")
print(response.text)
# Out:
# Oh, how lovely! Dogs are wonderful companions.
#
# Do you enjoy having them?

# %%
response = chat.send_message("How many paws are in my house?")
print(response.text)
# Out:
# Okay, assuming both of your dogs have all four of their paws:
#
# You would have a total of **8 paws** in your house (2 dogs * 4 paws per dog = 8 paws).

# %%
chat.send_message

# %%
from google import genai

client = genai.Client(api_key="AIzaSyA4SzcHUXZL6aKmqGVkstSkwZDHerijEfE")
chat = client.chats.create(model="gemini-2.5-flash-preview-04-17")

response = chat.send_message("I have 2 dogs in my house.")
print(response.text)

response = chat.send_message("How many paws are in my house?")
print(response.text)
# Out:
# Oh, nice! Dogs are wonderful companions.
#
# Two dogs must keep things lively! Do you want to tell me anything about them?
# Okay, if you have 2 dogs, and each dog typically has 4 paws, then you have:
#
# 2 dogs * 4 paws/dog = **8 paws**
#
# in your house, just from the dogs!

# %%
chat.get_history()
# Out:
# [UserContent(parts=[Part(video_metadata=None, thought=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, inline_data=None, text='I have 2 dogs in my house.')], role='user'),
#  Content(parts=[Part(video_metadata=None, thought=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, inline_data=None, text='Oh, nice! Dogs are wonderful companions.\n\nTwo dogs must keep things lively! Do you want to tell me anything about them?')], role='model'),
#  UserContent(parts=[Part(video_metadata=None, thought=None, code_execution_result=None, executable_code=None, file_data=None, function_call=None, function_response=None, inline_data=None, text='How many paws are in my house?')], role='user'),
# ...

# %%
chat.record_history

# %%
from google import genai

client = genai.Client(api_key="AIzaSyA4SzcHUXZL6aKmqGVkstSkwZDHerijEfE")

response = client.models.generate_content(
    model="gemini-2.5-flash-preview-04-17",
    contents=["How does AI work?"]
)
print(response.text)
# Out:
# Okay, let's break down how AI works in a way that's easy to understand.
#
# Think of AI not as a single magic technology, but more like a set of techniques and approaches aimed at making computers perform tasks that typically require human intelligence. The *most common* and powerful way modern AI works is through **learning from data**.
#
# Here's the core idea:
#
# 1.  **Instead of being explicitly programmed for every possible scenario**, AI systems (especially those based on Machine Learning) are designed to **learn patterns, rules, and insights directly from large amounts of data.**
#
# 2.  **They build a "model"** based on this data. This model is essentially the learned representation of the patterns and relationships found in the data.
#
# Here's a simplified look at the key components and the process:
#
# **Key Components:**
#
# 1.  **Data:** This is the fuel for AI. The AI system needs vast quantities of relevant data related to the problem it's trying to solve.
# ...

# %%
response.model_dump()
# Out:
# {'candidates': [{'content': {'parts': [{'video_metadata': None,
#       'thought': None,
#       'code_execution_result': None,
#       'executable_code': None,
#       'file_data': None,
#       'function_call': None,
#       'function_response': None,
#       'inline_data': None,
# ...
